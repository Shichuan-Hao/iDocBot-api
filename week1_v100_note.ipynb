# %%
conda create --name iDocBot python==3.11.7
conda activate iDocBot
conda deactivate

# %% [markdown]
# 建议使用 Python 3.10+或者11，不建议使用12，因为会有很多 BUG

# %% [markdown]
# 安装依赖包

# %%
pip install -r requirements.txt
