# %%
import zai
print(zai.__version__)
# Out:
# 0.2.3

# %%
from zai import ZhipuAiClient

client = ZhipuAiClient(api_key="a30b3bdc9c33463296fcb2cc0741d9ff.6Hxhw6bZFthbONPN")
response = client.embeddings.create(
    model="embedding-2",  # 填写需要调用的模型编码
    input=[
        "美食非常美味，服务员也很友好。",
        "这部电影既刺激又令人兴奋。",
        "阅读书籍是扩展知识的好方法。"
    ],
)
print(response)
# Out:
# EmbeddingsResponded(object='list', data=[Embedding(object='embedding', index=0, embedding=[-0.020775603, 0.06334462, -0.017122138, 0.016600132, 0.017251953, -0.014741155, -0.011511995, -0.016588641, 0.035585053, 0.083452925, -0.005399686, 0.0024879824, -0.030436432, -0.010664957, 0.034273338, -0.019605095, -0.012082101, -0.01078454, -0.0048643164, 0.05243559, -0.052741714, 0.057676643, -0.004305321, -0.019656535, -0.027257599, -0.0075013223, 0.019196954, -0.03248993, -0.009774154, -0.05538003, 0.0053269947, -0.008980223, -0.029414503, -0.020167891, -0.0023011295, 0.050812047, 0.02093515, 0.07071669, -0.016272785, -0.032133438, 0.0016233925, 0.0030969707, 0.006275949, 0.039037235, 0.033044428, -0.003366238, 0.04414481, 0.032620348, -0.013014651, 0.017422775, 0.009788254, 0.07336424, 0.002873115, 0.00042462614, 0.004788505, -0.062264234, 0.069745675, -0.0073324624, 0.010835776, 0.020451766, 0.011282008, 0.026465034, -0.041616734, 0.015795384, 0.019603029, -0.027370993, 0.06281868, 0.01
# ...

# %%
# 旧
from zhipuai import ZhipuAI

client = ZhipuAI(api_key="a30b3bdc9c33463296fcb2cc0741d9ff.6Hxhw6bZFthbONPN")
response = client.embeddings.create(
    model="embedding-2",  # 填写需要调用的模型编码
    input=[
        "美食非常美味，服务员也很友好。",
        "这部电影既刺激又令人兴奋。",
        "阅读书籍是扩展知识的好方法。"
    ],
)
print(response)
# Out:
# EmbeddingsResponded(object='list', data=[Embedding(object='embedding', index=0, embedding=[-0.020775603, 0.06334462, -0.017122138, 0.016600132, 0.017251953, -0.014741155, -0.011511995, -0.016588641, 0.035585053, 0.083452925, -0.005399686, 0.0024879824, -0.030436432, -0.010664957, 0.034273338, -0.019605095, -0.012082101, -0.01078454, -0.0048643164, 0.05243559, -0.052741714, 0.057676643, -0.004305321, -0.019656535, -0.027257599, -0.0075013223, 0.019196954, -0.03248993, -0.009774154, -0.05538003, 0.0053269947, -0.008980223, -0.029414503, -0.020167891, -0.0023011295, 0.050812047, 0.02093515, 0.07071669, -0.016272785, -0.032133438, 0.0016233925, 0.0030969707, 0.006275949, 0.039037235, 0.033044428, -0.003366238, 0.04414481, 0.032620348, -0.013014651, 0.017422775, 0.009788254, 0.07336424, 0.002873115, 0.00042462614, 0.004788505, -0.062264234, 0.069745675, -0.0073324624, 0.010835776, 0.020451766, 0.011282008, 0.026465034, -0.041616734, 0.015795384, 0.019603029, -0.027370993, 0.06281868, 0.01
# ...

# %%
sql_inter_description = "用于执行一段SQL代码，并最终获取telco_db数据库数据查询结果，\
核心功能是将输入的SQL代码传输至MySQL环境中进行运行，\
并最终返回SQL代码运行结果。需要注意的是，本函数是借助pymysql来连接MySQL数据库。"

# %%
q1 = "请帮我下telco_db数据库中所有用户的性别和年龄信息。"

# %%
q2 = "请帮我介绍下什么是机器学习？"

# %%
text_tuples = (sql_inter_description, q1, q2)
# res = openai.Embedding.create(
#   model="text-embedding-ada-002",
#   input=text_tuples,
#   encoding_format="float"
# )
response = client.embeddings.create(
    model="embedding-2",  # 填写需要调用的模型编码
    input=text_tuples,
    encoding_format="float"
)

# %%
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

cosine_similarity([response.data[0].embedding, response.data[1].embedding, response.data[2].embedding])
# Out:
# array([[1.        , 0.52139838, 0.31458695],
#        [0.52139838, 1.        , 0.22893215],
#        [0.31458695, 0.22893215, 1.        ]])
